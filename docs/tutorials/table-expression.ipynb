# %%
from __future__ import annotations
import typing
from typing import NewType, Union, Optional, List, Callable
import dataclasses

import metadsl
import metadsl_rewrite
import metadsl_core
import pandas as pd

from toki import datatypes as dts
from toki import types as tt
from toki.backend import Backend, BackendTranslator
from toki.viz import visualize

# %%
def constructor(fn: Callable):
    """Decorator for expression constructor."""
    def _fn(*args, **kwargs):
        fn.__qualname__ = fn.__qualname__.split('.')[0]
        return metadsl.expression(fn)(*args, **kwargs)
    return _fn


class Expr(metadsl.Expression):
    """Meta expression."""
    
    @property
    def _display_name(self) -> str:
        return self.__class__.__name__
    
    @staticmethod
    def expr(*args, **kwargs):
        """Create an expression with the given value."""
        raise NotImplementedError('Operation not supported yet.')
    
    def __repr__(self) -> str:
        fn_name = self.function if not str(self.function) == 'expr' else self._display_name
            
        output = '{}({})'.format(fn_name, self.args)
        return output


class DataTypeExpr(Expr):
    """Data type expression."""
    
    def __add__(self, other: Union[DataType, int, float]):
        raise NotImplementedError('Operation not supported yet.')

        
class OperationExpr(Expr):
    """Operation expression."""


class IntegerExpr(DataTypeExpr):
    """String expression."""
    
    @staticmethod
    @constructor
    def expr(value: int) -> IntegerExpr:
        """Create an IntegerExpr expression with the given value."""
    
    @property
    def value(self) -> int:
        return self.args[0]
    
    
class Add(OperationExpr):
    """Binary ``add`` operation."""
    
    @property
    def left(self) -> DataTypeExpr:
        return self.args[0]
    
    @property
    def right(self) -> DataTypeExpr:
        return self.args[1]
    
    @staticmethod
    @constructor
    def expr(left: DataTypeExpr, right:DataTypeExpr) -> Add:
        """Create an Add expression for the given parameters."""
    
def register(name, klass, f_source_name, f_target):
    f_target.__qualname__ = name
    setattr(klass, f_source_name, metadsl.expression(f_target))
    

def _integer_add(x: Union[int, IntegerExpr], y: Union[int, IntegerExpr]) -> Add:
    """Dispatch for addition between two integers."""

    
register('Add', IntegerExpr, '__add__', _integer_add)
IntegerExpr.__add__ = metadsl.expression(_integer_add)
i = IntegerExpr.expr(1)
expr_add = Add.expr(i, i)
print(i)
print(expr_add)
print(i + i)
# Out:
# IntegerExpr(1)
# Add(IntegerExpr(1), IntegerExpr(1))
# Add(IntegerExpr(1), IntegerExpr(1))

# %%
sch = tt.TableSchema.expr({
    'col_1': {'type': 'int64', 'nullable': True},
    'col_2': {'type': 'float64', 'nullable': True},
})

print(sch)
# Out:
# TableSchema
#   col_1: int64(nullale)
#   col_2: float64(nullale)

# %%
type(sch.function)
# Out:
# metadsl.typing_tools.Infer

# %%
table = tt.Table.expr(
    'my_table', 
    sch, 
    database_name='postgres', 
    database_schema_name='public'
)
table
# Out:
# postgres.public.my_table: Table
#   col_1: int64(nullale)
#   col_2: float64(nullale)

# %%
expr = table[['col_1', 'col_2']]['col_1']
expr
# Out:
# Projection[col_1]
#   Projection[['col_1', 'col_2']]
#     postgres.public.my_table: Table
#       col_1: int64(nullale)
#       col_2: float64(nullale)

# %%
import stackeddag.core as sd

# %%
import pydot
import stackeddag.core as sd

def graph2ascii(graph) -> str:
    v = pydot.graph_from_dot_data(str(graph))
    g = v[0]
    edges = g.get_edges()
    nodes = g.get_nodes()
    la = []
    for i in nodes:
        attr = i.get_attributes()
        if 'label' in attr:
            name = i.get_name()
            label = attr['label']
            if label.startswith('"'):
                label = label[1:]
            if label.endswith('"'):
                label = label[:-1]
            la.append((name, label))
    ed = []
    for i in edges:
        src = i.get_source()
        dst = i.get_destination()
        ed.append((src, [dst]))
    return sd.edgesToText(sd.mkLabels(la), sd.mkEdges(ed))

# %%
import graphviz as gv
from uuid import uuid4


def expr_to_graph(expr: tt.Expr) -> gv.Digraph:
    g = gv.Digraph(comment='Graph')
    g.attr('node', shape='box', rankdir='BT')
    
    edges = []

    nodes = [expr]
    parent = None
    while len(nodes):
        node = nodes.pop(0)
        node_id = str(id(node))
        g.node(node_id, '{}.{}'.format(node._display_name, node.function))
        if parent:
            edges.append((node_id, parent[0]))
        parent = (node_id, node)
        
        for i in node.args:
            if isinstance(i, tt.Expr):
                nodes.append(i)
            else:
                item_id = uuid4().hex
                if isinstance(i, dict):
                    for k, v in i.items():
                        item_id = str(id(k))
                        item_val = '{}:{}'.format(k, v)
                        g.node(item_id, item_val)
                        edges.append((item_id, node_id))
                else:
                    item_val = str(i)
                    g.node(item_id, item_val)
                    edges.append((item_id, node_id))
                

    g.edges(edges)
    return g
    
graph0 = expr_to_graph(expr)
print(graph2ascii(graph0), end="")
# Out:
# o o    col_{1:{'type': 'int64', 'nullable': True},2:{'type': 'float64', 'nullable': True}}
# |/
# o o o o    TableSchema.expr,my_table,postgres,public
# |/_/_/
# o o    postgres.public.my_table.expr,['col_1', 'col_2']
# |/
# o o    Projection[['col_1', 'col_2']].Table.__getitem__,col_1
# |/
# o    Projection[col_1].Projection.__getitem__

# %%
new_expr = (((((expr + 1) - 1) * 3) / 2) ** 2) % 2
new_expr
# Out:
# TableBase(function=TableBase.__mod__, args=[TableBase(function=TableBase.__pow__, args=[TableBase(function=TableBase.__truediv__, args=[TableBase(function=TableBase.__mul__, args=[TableBase(function=TableBase.__sub__, args=[TableBase(function=Projection.__add__, args=[Projection[col_1]
#   Projection[['col_1', 'col_2']]
#     postgres.public.my_table: Table
#       col_1: int64(nullale)
#       col_2: float64(nullale)
#
#
# , 1], kwargs={}), 1], kwargs={}), 3], kwargs={}), 2], kwargs={}), 2], kwargs={}), 2], kwargs={})

# %%
graph1 = expr_to_graph(new_expr)
print(str(graph1))
print(graph2ascii(graph1))
# Out:
# // Graph
# digraph {
# 	node [rankdir=BT shape=box]
# 	140699851143776 [label="TableBase.TableBase.__mod__"]
# 	"689d110eae3e4f39a7040f4b599bdc2d" [label=2]
# 	140699282292544 [label="TableBase.TableBase.__pow__"]
# 	d2dda3c72ddf4662a1d71ae5f438d0e0 [label=2]
# 	140699282292064 [label="TableBase.TableBase.__truediv__"]
# 	f1622043845049ebb7e861672d339a96 [label=2]
# 	140699282128800 [label="TableBase.TableBase.__mul__"]
# 	fbcec3c0f1684cd08f41100ea97c8113 [label=3]
# 	140699282127552 [label="TableBase.TableBase.__sub__"]
# 	"6f2eb8fcdbf844fa83997eb615909c68" [label=1]
# 	140699282127840 [label="TableBase.Projection.__add__"]
# 	"464a36bd52c24e6c9aa4c90a2cc603d9" [label=1]
# 	140699282126592 [label="Projection[col_1].Projection.__getitem__"]
# 	c30899e8acd64b7b90186b0868a040d5 [label=col_1]
# 	140699282128512 [label="Projection[['col_1', 'col_2']].Table.__getitem__"]
# 	"75f748ab656e49819cf4d5afb5a22567" [label="['col_1', 'col_2']"]
# 	140699282440640 [label="postgres.public.my_table.expr"]
# 	fad7ad48203949d9a6acc52d86abf423 [label=my_table]
# 	"6b244cd085fb49f1b38e881e544f0328" [label=postgres]
# 	b41ee02290434917bffd22cb3bf99d50 [label=public]
# 	140699282441888 [label="TableSchema.expr"]
# 	140699977452080 [label="col_1:{'type': 'int64', 'nullable': True}"]
# 	140699282568368 [label="col_2:{'type': 'float64', 'nullable': True}"]
# 	"689d110eae3e4f39a7040f4b599bdc2d" -> 140699851143776
# 	140699282292544 -> 140699851143776
# 	d2dda3c72ddf4662a1d71ae5f438d0e0 -> 140699282292544
# 	140699282292064 -> 140699282292544
# 	f1622043845049ebb7e861672d339a96 -> 140699282292064
# 	140699282128800 -> 140699282292064
# 	fbcec3c0f1684cd08f41100ea97c8113 -> 140699282128800
# 	140699282127552 -> 140699282128800
# 	"6f2eb8fcdbf844fa83997eb615909c68" -> 140699282127552
# 	140699282127840 -> 140699282127552
# 	"464a36bd52c24e6c9aa4c90a2cc603d9" -> 140699282127840
# 	140699282126592 -> 140699282127840
# 	c30899e8acd64b7b90186b0868a040d5 -> 140699282126592
# 	140699282128512 -> 140699282126592
# 	"75f748ab656e49819cf4d5afb5a22567" -> 140699282128512
# 	140699282440640 -> 140699282128512
# 	fad7ad48203949d9a6acc52d86abf423 -> 140699282440640
# 	"6b244cd085fb49f1b38e881e544f0328" -> 140699282440640
# 	b41ee02290434917bffd22cb3bf99d50 -> 140699282440640
# 	140699282441888 -> 140699282440640
# 	140699977452080 -> 140699282441888
# 	140699282568368 -> 140699282441888
# }
# o o    col_{1:{'type': 'int64', 'nullable': True},2:{'type': 'float64', 'nullable': True}}
# |/
# o o o o    TableSchema.expr,my_table,postgres,public
# |/_/_/
# o o    postgres.public.my_table.expr,['col_1', 'col_2']
# |/
# o o    Projection[['col_1', 'col_2']].Table.__getitem__,col_1
# |/
# o o    Projection[col_1].Projection.__getitem__,1
# |/
# o o    TableBase.Projection.__add__,1
# |/
# o o    TableBase.TableBase.__sub__,3
# |/
# o o    TableBase.TableBase.__mul__,2
# |/
# o o    TableBase.TableBase.__truediv__,2
# |/
# o o    TableBase.TableBase.__pow__,2
# |/
# o    TableBase.TableBase.__mod__

# %%
graph1
